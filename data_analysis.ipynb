# %% [markdown]
# ## Draft and Data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_accuracy_sc_qa(path):
    df = pd.read_json(path, lines=True)
    df["pred"] = df["pred"].astype(str)
    df["label"] = df["label"].astype(str)
    # compute accuracy
    ## Price
    price_correct = 0
    for pred, label in zip(df["pred"][:100], df["label"][:100]):
        if str(label) in str(pred):
            price_correct += 1
    price_correct /= 100
    ## Lead Time
    lead_time_correct = 0
    for pred, label in zip(df["pred"][100:200], df["label"][100:200]):
        if label in pred:
            lead_time_correct += 1
    lead_time_correct /= 100
    ## event
    event_correct = 0
    # for pred, label in zip(df["pred"][200:300], df["label"][200:300]):
    #     if label in pred:
    #         event_correct += 1
    # event_correct /= 100
    ## order fulfill
    order_fulfill_correct = 0
    # for pred, label in zip(df["pred"][300:400], df["label"][300:400]):
    #     if label in pred:
    #         order_fulfill_correct += 1
    # order_fulfill_correct /= 100
    ## demand
    demand_correct = 0
    # for pred, label in zip(df["pred"][400:500], df["label"][400:500]):
    #     if str(label) in str(pred):
    #         demand_correct += 1
    # demand_correct /= 100
    
    return price_correct, lead_time_correct, event_correct, order_fulfill_correct, demand_correct

# %%
price_acc, lead_time_acc, event_acc, order_fulfill_acc, demand_acc = \
    get_accuracy_sc_qa('output/supplychain_graphs/model_name_graph_llm_llm_model_name_7b_chat_llm_frozen_True_max_txt_len_1024_max_new_tokens_512_gnn_model_name_gt_patience_2_num_epochs_15_seed4/best_results.csv')

# %%
print("price acc", price_acc)
print("lead time acc", lead_time_acc)
print("event acc", event_acc)
print("order fulfill acc", order_fulfill_acc)
print("demand acc", demand_acc)
# Out:
# price acc 0.34
# lead time acc 0.58
# event acc 0
# order fulfill acc 0
# demand acc 0

# %%
df = pd.read_json('output/supplychain_graphs/model_name_graph_llm_llm_model_name_7b_chat_llm_frozen_True_max_txt_len_1024_max_new_tokens_512_gnn_model_name_gt_patience_2_num_epochs_15_seed4/best_results.csv', lines=True)

# %%
print(df.loc[0, 'question'])
print(df.loc[0, 'desc'])
# Out:
# Your are stage_1_agent_1 at round 9. Based on the provided supply chain graph, which of the upstream agents at stage 2 offer the lowerest price? Answer with the node id, e.g. 15.
# node_id,node_attr
# 0,Customers
# 1,stage_0_agent_0
# 2,stage_0_agent_1
# 3,stage_0_agent_2
# 4,stage_0_agent_3
# 5,stage_1_agent_0
# 6,"stage_1_agent_1: price: 54, production cost: 1, production capacity: 30, inventory: 14, backlog: 3, upstream backlog: 0"
# 7,stage_1_agent_2
# 8,stage_1_agent_3
# 9,stage_2_agent_0: price: 24
# 10,stage_2_agent_1: price: 10
# 11,stage_2_agent_2: price: 15
# 12,stage_2_agent_3: price: 15
# 13,stage_3_agent_0
# 14,stage_3_agent_1
# 15,stage_3_agent_2
# 16,stage_3_agent_3
# 17,New product version launches
#
# src,edge_attr,dst
# 9,is an upstream agent to,6
# 10,is an upstream agent to,6
# 11,is an upstream agent to,6
# 12,is an upstream agent to,6

# %%
print(df.loc[0, 'pred'])
print(df.loc[0, 'label'])
# Out:
# 8
# 9
